# %% [markdown]
# # Desafio 5
#
# Neste desafio, vamos praticar sobre redução de dimensionalidade com PCA e seleção de variáveis com RFE. Utilizaremos o _data set_ [Fifa 2019](https://www.kaggle.com/karangadiya/fifa19), contendo originalmente 89 variáveis de mais de 18 mil jogadores do _game_ FIFA 2019.
#
# > Obs.: Por favor, não modifique o nome das funções de resposta.

# %% [markdown]
# ## _Setup_ geral

# %%
from math import sqrt

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sct
import seaborn as sns
import statsmodels.api as sm
import statsmodels.stats as st
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

from loguru import logger

# %%
# Algumas configurações para o matplotlib.
#%matplotlib inline
from IPython.core.pylabtools import figsize
figsize(12, 8)
sns.set()

# %%
df = pd.read_csv("data.csv")

# %%
columns_to_drop = ["Unnamed: 0", "ID", "Name", "Photo", "Nationality", "Flag",
                   "Club", "Club Logo", "Value", "Wage", "Special", "Preferred Foot",
                   "International Reputation", "Weak Foot", "Skill Moves", "Work Rate",
                   "Body Type", "Real Face", "Position", "Jersey Number", "Joined",
                   "Loaned From", "Contract Valid Until", "Height", "Weight", "LS",
                   "ST", "RS", "LW", "LF", "CF", "RF", "RW", "LAM", "CAM", "RAM", "LM",
                   "LCM", "CM", "RCM", "RM", "LWB", "LDM", "CDM", "RDM", "RWB", "LB", "LCB",
                   "CB", "RCB", "RB", "Release Clause"
]

try:
    df.drop(columns_to_drop, axis=1, inplace=True)
except KeyError:
    logger.warning(f"Columns already dropped")

# %% [markdown]
# ## Inicia sua análise a partir daqui

# %%
df.head()
# Out:
#    Age  Overall  Potential  Crossing  Finishing  HeadingAccuracy  \
# 0   31       94         94      84.0       95.0             70.0
# 1   33       94         94      84.0       94.0             89.0
# 2   26       92         93      79.0       87.0             62.0
# 3   27       91         93      17.0       13.0             21.0
# 4   27       91         92      93.0       82.0             55.0
#
#    ShortPassing  Volleys  Dribbling  Curve  ...  Penalties  Composure  \
# 0          90.0     86.0       97.0   93.0  ...       75.0       96.0
# 1          81.0     87.0       88.0   81.0  ...       85.0       95.0
# 2          84.0     84.0       96.0   88.0  ...       81.0       94.0
# 3          50.0     13.0       18.0   21.0  ...       40.0       68.0
# 4          92.0     82.0       86.0   85.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              18207 non-null  int64
#  1   Overall          18207 non-null  int64
#  2   Potential        18207 non-null  int64
#  3   Crossing         18159 non-null  float64
#  4   Finishing        18159 non-null  float64
#  5   HeadingAccuracy  18159 non-null  float64
#  6   ShortPassing     18159 non-null  float64
#  7   Volleys          18159 non-null  float64
#  8   Dribbling        18159 non-null  float64
#  9   Curve            18159 non-null  float64
#  10  FKAccuracy       18159 non-null  float64
#  11  LongPassing      18159 non-null  float64
#  12  BallControl      18159 non-null  float64
#  13  Acceleration     18159 non-null  float64
#  14  SprintSpeed      18159 non-null  float64
#  15  Agility          18159 non-null  float64
#  16  Reactions        18159 non-null  float64
#  17  Balance          18159 non-null  float64
#  18  ShotPower        18159 non-null  float64
#  19  Jumping          18159 non-null  float64
#  20  Stamina          18159 non-null  float64
#  21  Strength         18159 non-null  float64
#  22  LongShots        18159 non-null  float64
#  23  Aggression       18159 non-null  float64
#  24  Interceptions    18159 non-null  float64
#  25  Positioning      18159 non-null  float64
#  26  Vision           18159 non-null  float64
#  27  Penalties        18159 non-null  float64
#  28  Composure        18159 non-null  float64
#  29  Marking          18159 non-null  float64
#  30  StandingTackle   18159 non-null  float64
#  31  SlidingTackle    18159 non-null  float64
#  32  GKDiving         18159 non-null  float64
#  33  GKHandling       18159 non-null  float64
#  34  GKKicking        18159 non-null  float64
#  35  GKPositioning    18159 non-null  float64
#  36  GKReflexes       18159 non-null  float64
# dtypes: float64(34), int64(3)
# memory usage: 5.1 MB

# %%
df.isna().sum()
# Out:
# Age                 0
# Overall             0
# Potential           0
# Crossing           48
# Finishing          48
# HeadingAccuracy    48
# ShortPassing       48
# Volleys            48
# Dribbling          48
# Curve              48
# FKAccuracy         48
# LongPassing        48
# BallControl        48
# Acceleration       48
# SprintSpeed        48
# Agility            48
# Reactions          48
# Balance            48
# ShotPower          48
# Jumping            48
# Stamina            48
# Strength           48
# LongShots          48
# Aggression         48
# Interceptions      48
# Positioning        48
# Vision             48
# Penalties          48
# Composure          48
# Marking            48
# StandingTackle     48
# SlidingTackle      48
# GKDiving           48
# GKHandling         48
# GKKicking          48
# GKPositioning      48
# GKReflexes         48
# dtype: int64

# %%
df.loc[df.isnull().any(axis=1)]
# Out:
#        Age  Overall  Potential  Crossing  Finishing  HeadingAccuracy  \
# 13236   33       62         62       NaN        NaN              NaN
# 13237   29       62         62       NaN        NaN              NaN
# 13238   35       62         62       NaN        NaN              NaN
# 13239   20       62         72       NaN        NaN              NaN
# 13240   24       62         66       NaN        NaN              NaN
# 13241   21       62         72       NaN        NaN              NaN
# 13242   23       62         70       NaN        NaN              NaN
# 13243   19       62         78       NaN        NaN              NaN
# 13244   30       62         62       NaN        NaN              NaN
# 13245   21       62         69       NaN        NaN              NaN
# 13246   22       62         68       NaN        NaN              NaN
# 13247   28       62         62       NaN        NaN              NaN
# 13248   24       62         69       NaN        NaN              NaN
# 13249   27       62         62       NaN        NaN              NaN
# 13250   29       62         62       NaN        NaN              NaN
# 13251   34       62         62       NaN        NaN              NaN
# 13252   22       62         70       NaN        NaN              NaN
# 13253   31       62         62       NaN        NaN              NaN
# 13254   17       62         82       NaN        NaN              NaN
# 13255   25       62         65       NaN        NaN              NaN
# 13256   26       62         62       NaN        NaN              NaN
# 13257   25       62         65       NaN        NaN              NaN
# 13258   23       62         67       NaN        NaN              NaN
# 13259   27       62         65       NaN        NaN              NaN
# 13260   20       62         69       NaN        NaN              NaN
# 13261   25       62         64       NaN        NaN              NaN
# 13262   24       62         66       NaN        NaN              NaN
# 13263   25       62         66       NaN        NaN              NaN
# 13264   29       62         62       NaN        NaN              NaN
# 13265   28       62         62       NaN        NaN              NaN
# 13266   20       62         73       NaN        NaN              NaN
# 13267   22       62         70       NaN        NaN              NaN
# 13268   37       62         62       NaN        NaN              NaN
# 13269   26       62         64       NaN        NaN              NaN
# 13270   19       62         77       NaN        NaN              NaN
# 13271   26       62         63       NaN        NaN              NaN
# 13272   22       62         70       NaN        NaN              NaN
# 13273   25       62         67       NaN        NaN              NaN
# 13274   27       62         62       NaN        NaN              NaN
# 13275   23       62         70       NaN        NaN              NaN
# 13276   26       62         63       NaN        NaN              NaN
# 13277   26       62         62       NaN        NaN              NaN
# 13278   17       62         79       NaN        NaN              NaN
# 13279   22       62         69       NaN        NaN              NaN
# 13280   19       62         77       NaN        NaN              NaN
# 13281   27       62         62       NaN        NaN              NaN
# 13282   25       62         65       NaN        NaN              NaN
# 13283   25       62         66       NaN        NaN              NaN
#
#        ShortPassing  Volleys  Dribbling  Curve  ...  Penalties  Composure  \
# 13236           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13237           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13238           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13239           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13240           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13241           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13242           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13243           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13244           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13245           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13246           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13247           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13248           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13249           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13250           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13251           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13252           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13253           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13254           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13255           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13256           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13257           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13258           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13259           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13260           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13261           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13262           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13263           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13264           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13265           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13266           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13267           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13268           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13269           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13270           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13271           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13272           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13273           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13274           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13275           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13276           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13277           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13278           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13279           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13280           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13281           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13282           NaN      NaN        NaN    NaN  ...        NaN        NaN
# 13283           NaN      NaN        NaN    NaN  ...        NaN        NaN
#
#        Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 13236      NaN             NaN            NaN       NaN         NaN
# 13237      NaN             NaN            NaN       NaN         NaN
# 13238      NaN             NaN            NaN       NaN         NaN
# 13239      NaN             NaN            NaN       NaN         NaN
# 13240      NaN             NaN            NaN       NaN         NaN
# 13241      NaN             NaN            NaN       NaN         NaN
# 13242      NaN             NaN            NaN       NaN         NaN
# 13243      NaN             NaN            NaN       NaN         NaN
# 13244      NaN             NaN            NaN       NaN         NaN
# 13245      NaN             NaN            NaN       NaN         NaN
# 13246      NaN             NaN            NaN       NaN         NaN
# 13247      NaN             NaN            NaN       NaN         NaN
# 13248      NaN             NaN            NaN       NaN         NaN
# 13249      NaN             NaN            NaN       NaN         NaN
# 13250      NaN             NaN            NaN       NaN         NaN
# 13251      NaN             NaN            NaN       NaN         NaN
# 13252      NaN             NaN            NaN       NaN         NaN
# 13253      NaN             NaN            NaN       NaN         NaN
# 13254      NaN             NaN            NaN       NaN         NaN
# 13255      NaN             NaN            NaN       NaN         NaN
# 13256      NaN             NaN            NaN       NaN         NaN
# 13257      NaN             NaN            NaN       NaN         NaN
# 13258      NaN             NaN            NaN       NaN         NaN
# 13259      NaN             NaN            NaN       NaN         NaN
# 13260      NaN             NaN            NaN       NaN         NaN
# 13261      NaN             NaN            NaN       NaN         NaN
# 13262      NaN             NaN            NaN       NaN         NaN
# 13263      NaN             NaN            NaN       NaN         NaN
# 13264      NaN             NaN            NaN       NaN         NaN
# 13265      NaN             NaN            NaN       NaN         NaN
# 13266      NaN             NaN            NaN       NaN         NaN
# 13267      NaN             NaN            NaN       NaN         NaN
# 13268      NaN             NaN            NaN       NaN         NaN
# 13269      NaN             NaN            NaN       NaN         NaN
# 13270      NaN             NaN            NaN       NaN         NaN
# 13271      NaN             NaN            NaN       NaN         NaN
# 13272      NaN             NaN            NaN       NaN         NaN
# 13273      NaN             NaN            NaN       NaN         NaN
# 13274      NaN             NaN            NaN       NaN         NaN
# 13275      NaN             NaN            NaN       NaN         NaN
# 13276      NaN             NaN            NaN       NaN         NaN
# 13277      NaN             NaN            NaN       NaN         NaN
# 13278      NaN             NaN            NaN       NaN         NaN
# 13279      NaN             NaN            NaN       NaN         NaN
# 13280      NaN             NaN            NaN       NaN         NaN
# 13281      NaN             NaN            NaN       NaN         NaN
# 13282      NaN             NaN            NaN       NaN         NaN
# 13283      NaN             NaN            NaN       NaN         NaN
#
#        GKKicking  GKPositioning  GKReflexes
# 13236        NaN            NaN         NaN
# 13237        NaN            NaN         NaN
# 13238        NaN            NaN         NaN
# 13239        NaN            NaN         NaN
# 13240        NaN            NaN         NaN
# 13241        NaN            NaN         NaN
# 13242        NaN            NaN         NaN
# 13243        NaN            NaN         NaN
# 13244        NaN            NaN         NaN
# 13245        NaN            NaN         NaN
# 13246        NaN            NaN         NaN
# 13247        NaN            NaN         NaN
# 13248        NaN            NaN         NaN
# 13249        NaN            NaN         NaN
# 13250        NaN            NaN         NaN
# 13251        NaN            NaN         NaN
# 13252        NaN            NaN         NaN
# 13253        NaN            NaN         NaN
# 13254        NaN            NaN         NaN
# 13255        NaN            NaN         NaN
# 13256        NaN            NaN         NaN
# 13257        NaN            NaN         NaN
# 13258        NaN            NaN         NaN
# 13259        NaN            NaN         NaN
# 13260        NaN            NaN         NaN
# 13261        NaN            NaN         NaN
# 13262        NaN            NaN         NaN
# 13263        NaN            NaN         NaN
# 13264        NaN            NaN         NaN
# 13265        NaN            NaN         NaN
# 13266        NaN            NaN         NaN
# 13267        NaN            NaN         NaN
# 13268        NaN            NaN         NaN
# 13269        NaN            NaN         NaN
# 13270        NaN            NaN         NaN
# 13271        NaN            NaN         NaN
# 13272        NaN            NaN         NaN
# 13273        NaN            NaN         NaN
# 13274        NaN            NaN         NaN
# 13275        NaN            NaN         NaN
# 13276        NaN            NaN         NaN
# 13277        NaN            NaN         NaN
# 13278        NaN            NaN         NaN
# 13279        NaN            NaN         NaN
# 13280        NaN            NaN         NaN
# 13281        NaN            NaN         NaN
# 13282        NaN            NaN         NaN
# 13283        NaN            NaN         NaN
#
# [48 rows x 37 columns]

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (18159, 37)

# %%
df.describe()
# Out:
#                 Age       Overall     Potential      Crossing     Finishing  \
# count  18159.000000  18159.000000  18159.000000  18159.000000  18159.000000
# mean      25.122529     66.249904     71.319126     49.734181     45.550911
# std        4.670568      6.914613      6.134420     18.364524     19.525820
# min       16.000000     46.000000     48.000000      5.000000      2.000000
# 25%       21.000000     62.000000     67.000000     38.000000     30.000000
# 50%       25.000000     66.000000     71.000000     54.000000     49.000000
# 75%       28.000000     71.000000     75.000000     64.000000     62.000000
# max       45.000000     94.000000     95.000000     93.000000     95.000000
#
#        HeadingAccuracy  ShortPassing       Volleys     Dribbling  \
# count     18159.000000  18159.000000  18159.000000  18159.000000
# mean         52.298144     58.686712     42.909026     55.371001
# std          17.379909     14.699495     17.694408     18.910371
# min           4.000000      7.000000      4.000000      4.000000
# 25%          44.000000     54.000000     30.000000     49.000000
# 50%          56.000000     62.000000     44.000000     61.000000
# 75%          64.000000     68.000000     57.000000     68.000000
# max          94.000000     93.000000     90.000000     97.000000
#
#               Curve  ...     Penalties     Composure       Marking  \
# count  18159.000000  ...  18159.000000  18159.000000  18159.000000
# mean      47.170824  ...     48.548598     58.648274     47.281623
# std       18.395264  ...     15.704053     11.436133     19.904397
# min        6.000000  ...      5.000000      3.000000      3.000000
# 25%       34.000000  ...     39.000000     51.000000     30.000000
# 50%       48.000000  ...     49.000000     60.000000     53.000000
# 75%       62.000000  ...     60.000000     67.000000     64.000000
# max       94.000000  ...     92.000000     96.000000     94.000000
#
#        StandingTackle  SlidingTackle      GKDiving    GKHandling  \
# count    18159.000000   18159.000000  18159.000000  18159.000000
# mean        47.697836      45.661435     16.616223     16.391596
# std         21.664004      21.289135     17.695349     16.906900
# min          2.000000       3.000000      1.000000      1.000000
# 25%         27.000000      24.000000      8.000000      8.000000
# 50%         55.000000      52.000000     11.000000     11.000000
# 75%         66.000000      64.000000     14.000000     14.000000
# max         93.000000      91.000000     90.000000     92.000000
#
#           GKKicking  GKPositioning    GKReflexes
# count  18159.000000   18159.000000  18159.000000
# mean      16.232061      16.388898     16.710887
# std       16.502864      17.034669     17.955119
# min        1.000000       1.000000      1.000000
# 25%        8.000000       8.000000      8.000000
# 50%       11.000000      11.000000     11.000000
# 75%       14.000000      14.000000     14.000000
# max       91.000000      90.000000     94.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# ## Questão 1
#
# Qual fração da variância consegue ser explicada pelo primeiro componente principal de `fifa`? Responda como um único float (entre 0 e 1) arredondado para três casas decimais.

# %%
def q1():
    pca = PCA()
    pca.fit(df)
    evr = pca.explained_variance_ratio_
    return float(round(evr[0], 3))
q1()
# Out:
# 0.565

# %% [markdown]
# ## Questão 2
#
# Quantos componentes principais precisamos para explicar 95% da variância total? Responda como un único escalar inteiro.

# %%
def q2():
    pca = PCA(n_components = 0.95)
    components = pca.fit_transform(df)
    return components.shape[1]
q2()
# Out:
# 15

# %% [markdown]
# ## Questão 3
#
# Qual são as coordenadas (primeiro e segundo componentes principais) do ponto `x` abaixo? O vetor abaixo já está centralizado. Cuidado para __não__ centralizar o vetor novamente (por exemplo, invocando `PCA.transform()` nele). Responda como uma tupla de float arredondados para três casas decimais.

# %%
x = [0.87747123,  -1.24990363,  -1.3191255, -36.7341814,
     -35.55091139, -37.29814417, -28.68671182, -30.90902583,
     -42.37100061, -32.17082438, -28.86315326, -22.71193348,
     -38.36945867, -20.61407566, -22.72696734, -25.50360703,
     2.16339005, -27.96657305, -33.46004736,  -5.08943224,
     -30.21994603,   3.68803348, -36.10997302, -30.86899058,
     -22.69827634, -37.95847789, -22.40090313, -30.54859849,
     -26.64827358, -19.28162344, -34.69783578, -34.6614351,
     48.38377664,  47.60840355,  45.76793876,  44.61110193,
     49.28911284
]

# %% [markdown]
# [`numpy.dot()` method reference](https://www.tutorialspoint.com/numpy/numpy_dot.htm)

# %%
def q3():
    pca = PCA(n_components=2)
    pca.fit(df)
    p1_p2 = pca.components_.dot(x).round(3)
    return tuple(p1_p2)
q3()
# Out:
# (186.556, -6.592)

# %% [markdown]
# ## Questão 4
#
# Realiza RFE com estimador de regressão linear para selecionar cinco variáveis, eliminando uma a uma. Quais são as variáveis selecionadas? Responda como uma lista de nomes de variáveis.

# %%
# Split target and features
X = df.drop(columns = 'Overall')
Y = df['Overall']

# %%
def q4():
    reg = LinearRegression()
    feat = RFE(reg, n_features_to_select = 5)
    feat = feat.fit(X, Y)
    idx = feat.get_support(indices=True)
    col_name = list(X.columns[idx])
    return col_name

q4()
# Out:
# ['Age', 'Potential', 'BallControl', 'Reactions', 'GKReflexes']

# %% [markdown]
# ## Reference:
# * [In Depth: Principal Component Analysis](https://jakevdp.github.io/PythonDataScienceHandbook/05.09-principal-component-analysis.html)
# * [In-Depth: Manifold Learning](https://jakevdp.github.io/PythonDataScienceHandbook/05.10-manifold-learning.html)
# * [Recursive Feature Elimination](https://bookdown.org/max/FES/recursive-feature-elimination.html)
# * [A Tutorial on Principal Component Analysis](http://www.cs.otago.ac.nz/cosc453/student_tutorials/principal_components.pdf)
# * [Principal Component Analysis explained](https://www.kaggle.com/nirajvermafcb/principal-component-analysis-explained)
# * [Step Forward Feature Selection](https://www.kdnuggets.com/2018/06/step-forward-feature-selection-python.html)
